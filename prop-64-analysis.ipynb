# %% [markdown]
# # Prop 64 Analysis
# By Amy Qin
#
# This is a sample notebook as prepared for Python for data journalists.

# %%
import pandas as pd

# %% [markdown]
# Reading in the list of propositions and committees from CSV

# %%
# %matplotlib inline

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# Read in the list of contributions to ballow measures from CSV.

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
merged = pd.merge(contribs, prop, on="calaccess_committee_id")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# contributor_employer            657 non-null object
# contributor_occupation          742 non-null object
# contributor_is_self_employed    860 non-null bool
# amount                          860 non-null float64
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# ...

# %%
merged.amount.sum()
# Out:
# 35177017.640000001

# %%
merged.head()
# Out:
#    calaccess_committee_id                            committee_name_x  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
merged.amount.sum()
# Out:
# 35177017.640000001

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    762
# OPPOSE      98
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 762 entries, 0 to 859
# Data columns (total 20 columns):
# calaccess_committee_id          762 non-null int64
# committee_name_x                762 non-null object
# calaccess_filing_id             762 non-null int64
# date_received                   762 non-null object
# contributor_lastname            762 non-null object
# contributor_firstname           694 non-null object
# contributor_city                762 non-null object
# contributor_state               762 non-null object
# contributor_zip                 762 non-null object
# contributor_employer            611 non-null object
# contributor_occupation          686 non-null object
# contributor_is_self_employed    762 non-null bool
# amount                          762 non-null float64
# ocd_prop_id                     762 non-null object
# calaccess_prop_id               762 non-null int64
# ccdc_prop_id                    762 non-null int64
# ...

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.amount.sum()
# Out:
# 32675806.0

# %%
oppose.amount.sum()
# Out:
# 2501211.6400000001

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.92889642704798669

# %%
merged.sort_values("amount")
# Out:
#      calaccess_committee_id  \
# 447                 1376077
# 430                 1343793
# 443                 1343793
# 335                 1343793
# 364                 1343793
# 3                   1386560
# 837                 1381808
# 830                 1381808
# 711                 1381808
# 728                 1381808
# 737                 1381808
# 638                 1381808
# 706                 1381808
# 684                 1381808
# 729                 1381808
# 671                 1381808
# 665                 1381808
# 740                 1381808
# 718                 1381808
# 859                 1381808
# 438                 1343793
# 444                 1343793
# 749                 1381808
# 431                 1343793
# 416                 1343793
# 414                 1343793
# 412                 1343793
# 411                 1343793
# 327                 1343793
# 314                 1343793
# ..                      ...
# 612                 1381808
# ...

# %%
merged.sort_values("amount", ascending=False).head()
# Out:
#      calaccess_committee_id  \
# 752                 1381808
# 689                 1381808
# 453                 1385506
# 458                 1385745
# 459                 1385745
#
#                                       committee_name_x  calaccess_filing_id  \
# 752  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...              2083528
# 689  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...              2083528
# 453  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...              2083608
# 458       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))              2082414
# 459       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))              2096507
#
#     date_received                               contributor_lastname  \
# 752    2016-09-15                     PARKER AND AFFILIATED ENTITIES
# 689    2016-09-15  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...
# 453    2016-09-15      FUND FOR POLICY REFORM (NONPROFIT 501 (C)(4))
# ...

# %%
oppose.sort_values("amount", ascending=False)
# Out:
#      calaccess_committee_id  \
# 608                 1387789
# 567                 1382568
# 565                 1382568
# 563                 1382568
# 609                 1387789
# 606                 1387789
# 607                 1387789
# 542                 1382568
# 605                 1387789
# 559                 1382568
# 561                 1382568
# 522                 1382568
# 546                 1382568
# 604                 1387789
# 589                 1382568
# 555                 1382568
# 516                 1382568
# 562                 1382568
# 547                 1382568
# 524                 1382568
# 526                 1382568
# 576                 1382568
# 519                 1382568
# 540                 1382568
# 577                 1382568
# 552                 1382568
# 553                 1382568
# 557                 1382568
# 558                 1382568
# 517                 1382568
# ..                      ...
# 523                 1382568
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                      committee_name_x       amount
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                      committee_name_x       amount
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 482                  SEAN                          PARKER            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 108                DANIEL                           LEWIS            SUPPORT
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# 405              NICHOLAS                        PRITZKER            SUPPORT
# 421                 PETER                           THIEL            SUPPORT
# 456                 ROGER                         JENKINS            SUPPORT
# 23                 ANGELA                          HOWARD            SUPPORT
# 322              LAWRENCE                            HESS            SUPPORT
# 221                 JASON                            POST            SUPPORT
# ...

# %%
outofstate = merged[merged.contributor_state != "CA"]

# %%
outofstate.amount.sum()/merged.amount.sum()
# Out:
# 0.50276646022115701

# %%
outofstate.groupby("committee_position").amount.sum()
# Out:
# committee_position
# OPPOSE      2112614.64
# SUPPORT    15573210.00
# Name: amount, dtype: float64

# %%
outofstate.committee_position.value_counts()
# Out:
# SUPPORT    149
# OPPOSE      18
# Name: committee_position, dtype: int64

# %%
merged.head()
# Out:
#    calaccess_committee_id                            committee_name_x  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
merged.groupby(["contributor_employer", "committee_position"]).amount.sum().head(15).reset_index()
# Out:
#                       contributor_employer committee_position  amount
# 0                  360SWEATER COMPANY, LLC            SUPPORT   360.0
# 1   3C - COMPREHENSIVE CANNABIS CONSULTING            SUPPORT   100.0
# 2                          4FRONT VENTURES            SUPPORT   100.0
# 3                             5AM VENTURES            SUPPORT   500.0
# 4                               745 AGENCY            SUPPORT   250.0
# 5                           7TH POINT, LLC            SUPPORT   100.0
# 6                               A NEW PATH            SUPPORT    84.0
# 7    ACLU OF SAN DIEGO & IMPERIAL COUNTIES            SUPPORT   250.0
# 8                      AD PRODUCTIONS, LLC            SUPPORT   100.0
# 9                               ADAM ELLIS            SUPPORT   100.0
# 10                            ADR SERVICES            SUPPORT   300.0
# 11                           AEROWIND CORP             OPPOSE   100.0
# ...

# %%
top_supporters = support.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters
# Out:
#     contributor_firstname            contributor_lastname     amount
# 444                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 443                  SEAN                          PARKER  1500000.0
# 102                DANIEL                           LEWIS  1250000.0
# 180                 HENRY                   VAN AMERINGEN  1000000.0
# 374              NICHOLAS                        PRITZKER   900000.0
# 390                 PETER                           THIEL   300000.0
# 421                 ROGER                         JENKINS    75000.0
# 22                 ANGELA                          HOWARD    65000.0
# 297              LAWRENCE                            HESS    30000.0
# 425              ROGER B.                         MCNAMEE    10000.0

# %%
top_supporters.amount.plot.bar()

# %%
top_supporters.amount.plot.barh()

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_lastname)

# %%
top_supporters['contributor_fullname'] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters.head()
# Out:
#     contributor_firstname            contributor_lastname     amount  \
# 444                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 443                  SEAN                          PARKER  1500000.0
# 102                DANIEL                           LEWIS  1250000.0
# 180                 HENRY                   VAN AMERINGEN  1000000.0
# 374              NICHOLAS                        PRITZKER   900000.0
#
#                     contributor_fullname
# 444  SEAN PARKER AND AFFILIATED ENTITIES
# 443                          SEAN PARKER
# 102                         DANIEL LEWIS
# 180                  HENRY VAN AMERINGEN
# 374                    NICHOLAS PRITZKER

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_fullname)

# %% [markdown]
# Export chart data to CSV.

# %%
top_supporters.head(5).to_csv("top_supporters.csv")

# %%
def combine_names(row):
    if row.contributor_fullname.startswith('SEAN PARKER'):
        return 'SEAN PARKER'
    return row.contributor_fullname

# %%
top_supporters.apply(combine_names, axis=1)
# Out:
# 444            SEAN PARKER
# 443            SEAN PARKER
# 102           DANIEL LEWIS
# 180    HENRY VAN AMERINGEN
# 374      NICHOLAS PRITZKER
# 390            PETER THIEL
# 421          ROGER JENKINS
# 22           ANGELA HOWARD
# 297          LAWRENCE HESS
# 425       ROGER B. MCNAMEE
# dtype: object

# %%
top_supporters['contributor_cleanname'] = top_supporters.apply(combine_names, axis=1)

# %%
top_supporters.head(5)
# Out:
#     contributor_firstname            contributor_lastname     amount  \
# 444                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 443                  SEAN                          PARKER  1500000.0
# 102                DANIEL                           LEWIS  1250000.0
# 180                 HENRY                   VAN AMERINGEN  1000000.0
# 374              NICHOLAS                        PRITZKER   900000.0
#
#                     contributor_fullname contributor_cleanname
# 444  SEAN PARKER AND AFFILIATED ENTITIES           SEAN PARKER
# 443                          SEAN PARKER           SEAN PARKER
# 102                         DANIEL LEWIS          DANIEL LEWIS
# 180                  HENRY VAN AMERINGEN   HENRY VAN AMERINGEN
# 374                    NICHOLAS PRITZKER     NICHOLAS PRITZKER

# %%
cleandata = top_supporters.groupby("contributor_cleanname").amount.sum().reset_index().sort_values("amount", ascending=False)

# %%
chart = cleandata.head(5).amount.plot.barh()
chart.set_yticklabels(cleandata.contributor_cleanname)
